# %%
from Player import Player
from GamePlay import GamePlay

# %%
a = Player()

# %%
training = GamePlay(a)
for _ in range(100000):
    training.play()

# %%
a.df_0["reward_X"].value_counts()
# Out:
# 0.621559    1
# Name: reward_X, dtype: int64

# %%
a.df_1
# Out:
#    0  1  2  3  4  5  6  7  8  reward_X                       successor_O  \
# 0                          X  0.150200     [0, 2, 6, 12, 20, 30, 42, 56]
# 1                       X    -0.107422     [1, 3, 7, 13, 21, 31, 43, 57]
# 2                    X        0.147113     [4, 5, 8, 14, 22, 32, 44, 58]
# 3                 X           0.105706   [9, 10, 11, 15, 23, 33, 45, 59]
# 4              X              0.621120  [16, 17, 18, 19, 24, 34, 46, 60]
# 5           X                 0.086731  [25, 26, 27, 28, 29, 35, 47, 61]
# 6        X                    0.172188  [36, 37, 38, 39, 40, 41, 48, 62]
# 7     X                       0.001268  [49, 50, 51, 52, 53, 54, 55, 63]
# 8  X                          0.084511  [64, 65, 66, 67, 68, 69, 70, 71]
#
#    game_over
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False

# %%
a.df_3.head()
# Out:
#     0  1  2  3  4  5  6  7  8  reward_X                  successor_O  \
# 0                     O  X  X -0.262822     [0, 6, 30, 90, 210, 420]
# 1                     X  O  X -0.021753     [1, 7, 31, 91, 211, 421]
# 2                     X  X  O -0.343945     [2, 8, 32, 92, 212, 422]
# 3                  O     X  X -0.095411     [0, 9, 33, 93, 213, 423]
# 4                  O  X     X  0.178768    [1, 10, 34, 94, 214, 424]
# 5                  O  X  X     0.017839    [2, 11, 35, 95, 215, 425]
# 6                  X     O  X -0.095316    [3, 12, 36, 96, 216, 426]
# 7                  X     X  O  0.029947    [4, 13, 37, 97, 217, 427]
# 8                  X  O     X  0.943725    [3, 14, 38, 98, 218, 428]
# 9                  X  O  X    -0.114511    [4, 15, 39, 99, 219, 429]
# 10                 X  X     O  0.014158   [5, 16, 40, 100, 220, 430]
# 11                 X  X  O    -0.054308   [5, 17, 41, 101, 221, 431]
# 12              O        X  X -0.617673    [6, 9, 42, 102, 222, 432]
# ...
